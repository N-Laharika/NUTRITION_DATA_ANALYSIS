# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Indian_Food_Nutrition_Processed.csv')

# %%
df.head()
# Out:
#                      Dish Name  Calories (kcal)  Carbohydrates (g)  \
# 0         Hot tea (Garam Chai)            16.14               2.58
# 1               Instant coffee            23.16               3.65
# 2               Espreso coffee            51.54               6.62
# 3                     Iced tea            10.34               2.70
# 4  Raw mango drink (Aam panna)            35.92               9.05
#
#    Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  \
# 0         0.39      0.53            2.58       0.00         3.12
# 1         0.64      0.75            3.62       0.00         4.92
# 2         1.75      2.14            6.53       0.00        13.98
# 3         0.03      0.01            2.70       0.00         0.23
# 4         0.16      0.03            7.49       0.61        79.82
#
#    Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)
# 0         14.20       0.02            0.50         1.80
# 1         20.87       0.06            1.51         5.60
# ...

# %%
df.tail()
# Out:
#                                               Dish Name  Calories (kcal)  \
# 1009  Sweet and sour tomato pickle (Khatta meetha ta...            60.88
# 1010  Jhatpat achar with carrot (Jhatpat achaar gaja...            91.21
# 1011                Tomato chutney (Tamatar ki chutney)           176.07
# 1012                                     Tomato ketchup            33.07
# 1013                Bengal 5 Spice Blend (Panch Phoran)           289.79
#
#       Carbohydrates (g)  Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  \
# 1009               6.55         1.26      3.24            4.31       2.20
# 1010               6.32         1.98      6.55            3.04       5.08
# 1011              31.85         0.97      6.01           30.02       1.49
# 1012               6.48         0.91      0.30            4.68       1.90
# 1013              20.00        18.26     22.16            1.40      18.40
#
#       Sodium (mg)  Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dish Name          1014 non-null   object
#  1   Calories (kcal)    1014 non-null   float64
#  2   Carbohydrates (g)  1014 non-null   float64
#  3   Protein (g)        1014 non-null   float64
#  4   Fats (g)           1014 non-null   float64
#  5   Free Sugar (g)     1014 non-null   float64
#  6   Fibre (g)          1014 non-null   float64
#  7   Sodium (mg)        1014 non-null   float64
#  8   Calcium (mg)       1014 non-null   float64
#  9   Iron (mg)          1014 non-null   float64
#  10  Vitamin C (mg)     932 non-null    float64
#  11  Folate (µg)        932 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 95.2+ KB

# %%
df.columns
# Out:
# Index(['Dish Name', 'Calories (kcal)', 'Carbohydrates (g)', 'Protein (g)',
#        'Fats (g)', 'Free Sugar (g)', 'Fibre (g)', 'Sodium (mg)',
#        'Calcium (mg)', 'Iron (mg)', 'Vitamin C (mg)', 'Folate (µg)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Dish Name             0
# Calories (kcal)       0
# Carbohydrates (g)     0
# Protein (g)           0
# Fats (g)              0
# Free Sugar (g)        0
# Fibre (g)             0
# Sodium (mg)           0
# Calcium (mg)          0
# Iron (mg)             0
# Vitamin C (mg)       82
# Folate (µg)          82
# dtype: int64

# %%
bool_series = pd.isnull(df["Vitamin C (mg)"])
bool_series1 = pd.isnull(df["Folate (µg)"])

# %%
missing_data = df[bool_series]

# %%
missing_data.head()
# Out:
#                 Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# 932    White sauce (thin)           115.17               6.58         3.31
# 933  White sauce (medium)           151.27               7.98         3.36
# 934   White sauce (thick)           209.69              10.24         3.43
# 935          Cheese sauce           194.76               7.08         7.68
# 936             Egg sauce           146.85               5.88         5.97
#
#      Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  \
# 932      8.41            4.58       0.07        23.91        110.20
# 933     11.76            4.32       0.14        22.59        103.53
# 934     17.19            3.90       0.24        20.45         92.74
# 935     15.12            4.53       0.12       317.38        255.14
# 936     11.08            3.19       0.12        51.54         89.49
#
#      Iron (mg)  Vitamin C (mg)  Folate (µg)
# 932       0.19             NaN          NaN
# ...

# %%
missing_data1 = df[bool_series1]

# %%
missing_data1.head()
# Out:
#                 Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# 932    White sauce (thin)           115.17               6.58         3.31
# 933  White sauce (medium)           151.27               7.98         3.36
# 934   White sauce (thick)           209.69              10.24         3.43
# 935          Cheese sauce           194.76               7.08         7.68
# 936             Egg sauce           146.85               5.88         5.97
#
#      Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  \
# 932      8.41            4.58       0.07        23.91        110.20
# 933     11.76            4.32       0.14        22.59        103.53
# 934     17.19            3.90       0.24        20.45         92.74
# 935     15.12            4.53       0.12       317.38        255.14
# 936     11.08            3.19       0.12        51.54         89.49
#
#      Iron (mg)  Vitamin C (mg)  Folate (µg)
# 932       0.19             NaN          NaN
# ...

# %%
non_missing_values = df.notnull()

# %%
non_missing_values.head()
# Out:
#    Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  Fats (g)  \
# 0       True             True               True         True      True
# 1       True             True               True         True      True
# 2       True             True               True         True      True
# 3       True             True               True         True      True
# 4       True             True               True         True      True
#
#    Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  Iron (mg)  \
# 0            True       True         True          True       True
# 1            True       True         True          True       True
# 2            True       True         True          True       True
# 3            True       True         True          True       True
# 4            True       True         True          True       True
#
#    Vitamin C (mg)  Folate (µg)
# 0            True         True
# 1            True         True
# 2            True         True
# ...

# %%
sns.heatmap(non_missing_values.isnull(), cmap='viridis', cbar=True, yticklabels=False)
# Out:
# <Axes: >

# %%
df_clean=df.dropna()

# %%
df_clean.head()
# Out:
#                      Dish Name  Calories (kcal)  Carbohydrates (g)  \
# 0         Hot tea (Garam Chai)            16.14               2.58
# 1               Instant coffee            23.16               3.65
# 2               Espreso coffee            51.54               6.62
# 3                     Iced tea            10.34               2.70
# 4  Raw mango drink (Aam panna)            35.92               9.05
#
#    Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  \
# 0         0.39      0.53            2.58       0.00         3.12
# 1         0.64      0.75            3.62       0.00         4.92
# 2         1.75      2.14            6.53       0.00        13.98
# 3         0.03      0.01            2.70       0.00         0.23
# 4         0.16      0.03            7.49       0.61        79.82
#
#    Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)
# 0         14.20       0.02            0.50         1.80
# 1         20.87       0.06            1.51         5.60
# ...

# %%
import scipy.stats as stats

# %%
df_clean = df_clean.rename(columns = {'Folate (µg)' : 'Vitamin B (µg)'})

# %%
df_clean.head()
# Out:
#                      Dish Name  Calories (kcal)  Carbohydrates (g)  \
# 0         Hot tea (Garam Chai)            16.14               2.58
# 1               Instant coffee            23.16               3.65
# 2               Espreso coffee            51.54               6.62
# 3                     Iced tea            10.34               2.70
# 4  Raw mango drink (Aam panna)            35.92               9.05
#
#    Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  \
# 0         0.39      0.53            2.58       0.00         3.12
# 1         0.64      0.75            3.62       0.00         4.92
# 2         1.75      2.14            6.53       0.00        13.98
# 3         0.03      0.01            2.70       0.00         0.23
# 4         0.16      0.03            7.49       0.61        79.82
#
#    Calcium (mg)  Iron (mg)  Vitamin C (mg)  Vitamin B (µg)
# 0         14.20       0.02            0.50            1.80
# ...

# %%
stats.probplot(df_clean['Vitamin B (µg)'], dist="norm", plot=plt)
plt.show()
sns.histplot(df_clean['Vitamin B (µg)'], bins=30)
# Out:
# <Axes: xlabel='Vitamin B (µg)', ylabel='Count'>

# %%
duplicate = df_clean[df_clean.duplicated()]

# %%
duplicate
# Out:
# Empty DataFrame
# Columns: [Dish Name, Calories (kcal), Carbohydrates (g), Protein (g), Fats (g), Free Sugar (g), Fibre (g), Sodium (mg), Calcium (mg), Iron (mg), Vitamin C (mg), Vitamin B (µg)]
# Index: []

# %%
sns.boxplot(df_clean["Calories (kcal)"])
plt.title('Boxplot')
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
Q1 = df_clean["Calories (kcal)"].quantile(0.25)
Q3 = df_clean["Calories (kcal)"].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# np.float64(222.0775)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
lower_bound
# Out:
# np.float64(-232.56874999999997)

# %%
upper_bound
# Out:
# np.float64(655.74125)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Fats (g)'], df['Calories (kcal)'], color='green')
plt.title('Fats (g) vs Calories (kcal)')
plt.xlabel('Fats (g)')
plt.ylabel('Calories (kcal)')
plt.grid(True)
plt.show()

# %%
top5 = df.sort_values(by='Calories (kcal)', ascending=True).tail(5)
plt.figure(figsize=(8, 6))
plt.bar(top10['Dish Name'], top5['Calories (kcal)'], color='orange')
plt.title('Calories by Dish (Top 5)')
plt.xlabel('Dish Name')
plt.ylabel('Calories (kcal)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Calories (kcal)'], bins=10, color='purple', edgecolor='black')
plt.title('Calorie Distribution')
plt.xlabel('Calories (kcal)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
top_calorie_dishes = df.nlargest(10, 'Calories (kcal)')[['Dish Name', 'Calories (kcal)']]
plt.figure(figsize=(8, 8))
plt.pie(top_calorie_dishes['Calories (kcal)'], labels=top_calorie_dishes['Dish Name'], autopct='%1.1f%%')
plt.title("Top 10 High-Calorie Indian Dishes")
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
